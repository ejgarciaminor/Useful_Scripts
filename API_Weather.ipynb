# %%
import requests
from pymeteosource.api import Meteosource
from pymeteosource.types import tiers, sections, langs, units
import pandas as pd
import datetime
today = datetime.date.today()
today = today.strftime("%Y-%m-%d")

# pip install pymeteosource
# pip install pymeteosource[pandas]

API_KEY = '3zwarn7ip5qrtgt3j8f1ne9natizvnsaqm05llya'
TIER = tiers.FREE

meteosource = Meteosource(API_KEY, TIER)

cities = ['madrid', 'barcelona', 'valencia']
daily_df = pd.DataFrame()

for city in cities:
    forecast = meteosource.get_point_forecast(
        place_id=city,
        sections=[sections.DAILY],
        lang=langs.ENGLISH,
        units=units.METRIC,
        tz='Europe/Madrid'
    )

    # Convertir los datos diarios a un DataFrame de pandas
    data = forecast.daily.to_pandas()

    # Añadir una columna con el nombre de la ciudad
    data['city'] = city

    # Añadir una columna con la fecha correspondiente
    data['date'] = data.index
    data['date_prediction'] = today

    # Concatenar al DataFrame principal
    daily_df = pd.concat([daily_df, data], ignore_index=True)

# Mostrar las primeras filas del DataFrame
daily_df.head()
# Out:
#   afternoon  all_day_cloud_cover_total  all_day_icon  \
# 0      None                         22             4
# 1      None                         47             5
# 2      None                         52             4
# 3      None                         18             4
# 4      None                         56             4
#
#    all_day_precipitation_total all_day_precipitation_type  \
# 0                          0.0                       none
# 1                          0.0                       none
# 2                          0.0                       none
# 3                          0.0                       none
# 4                          0.0                       none
#
#    all_day_temperature  all_day_temperature_max  all_day_temperature_min  \
# 0                 17.8                     24.8                      9.5
# 1                 19.5                     26.8                     12.0
# 2                 16.8                     19.5                     12.8
# 3                 16.5                     24.0                      8.8
# 4                 18.2                     25.5                     10.8
#
#   all_day_weather  all_day_wind_angle all_day_wind_dir  all_day_wind_speed  \
# 0    partly_sunny                 116              ESE                 1.3
# 1   mostly_cloudy                 189                S                 2.8
# 2    partly_sunny                 244              WSW                 3.7
# 3    partly_sunny                  80                E                 1.6
# 4    partly_sunny                  27              NNE                 2.1
#
#   evening  icon morning                                            summary  \
# 0    None     4    None                Partly sunny. Temperature 10/25 °C.
# 1    None     5    None  Partly sunny changing to cloudy by afternoon. ...
# 2    None     4    None  Mostly cloudy, fewer clouds in the afternoon. ...
# 3    None     4    None  Sunny, more clouds in the afternoon and evenin...
# 4    None     4    None  Partly sunny, more clouds in the afternoon. Te...
#
#          weather    city       date date_prediction
# 0   partly_sunny  madrid 2025-05-17      2025-05-17
# 1  mostly_cloudy  madrid 2025-05-18      2025-05-17
# 2   partly_sunny  madrid 2025-05-19      2025-05-17
# 3   partly_sunny  madrid 2025-05-20      2025-05-17
# 4   partly_sunny  madrid 2025-05-21      2025-05-17

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7 entries, 2025-05-17 to 2025-05-23
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   afternoon                    0 non-null      object
#  1   all_day_cloud_cover_total    7 non-null      int64
#  2   all_day_icon                 7 non-null      int64
#  3   all_day_precipitation_total  7 non-null      float64
#  4   all_day_precipitation_type   7 non-null      object
#  5   all_day_temperature          7 non-null      float64
#  6   all_day_temperature_max      7 non-null      float64
#  7   all_day_temperature_min      7 non-null      float64
#  8   all_day_weather              7 non-null      object
#  9   all_day_wind_angle           7 non-null      int64
#  10  all_day_wind_dir             7 non-null      object
#  11  all_day_wind_speed           7 non-null      float64
#  12  evening                      0 non-null      object
#  13  icon                         7 non-null      int64
#  14  morning                      0 non-null      object
#  15  summary                      7 non-null      object
#  16  weather                      7 non-null      object
#  17  city                         7 non-null      object
#  18  date                         7 non-null      datetime64[ns]
#  19  date_prediction              7 non-null      object
# dtypes: datetime64[ns](1), float64(5), int64(4), object(10)
# memory usage: 1.1+ KB
